# %%
from io import TextIOWrapper
import numpy as np
from torch.utils.tensorboard.writer import SummaryWriter
from torch import optim
import torch
import os
from scipy.special import softmax
import sys

# %load_ext autoreload
# %autoreload 2
import env
import network

BOARD_XSIZE=7
BOARD_YSIZE=6
DIMS=(BOARD_YSIZE,BOARD_XSIZE)

EPISODES_PER_AGENT = 20
TRAIN_EPOCHS = 500000
MODEL_SAVE_INTERVAL = 100
SUMMARY_STATS_INTERVAL = 10
RANDOM_SEED = 42

SUMMARY_DIR = './summary'
MODEL_DIR = './models'

# settings
#os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# create result directory
if not os.path.exists(SUMMARY_DIR):
    os.makedirs(SUMMARY_DIR)


use_cuda = torch.cuda.is_available()
torch.manual_seed(RANDOM_SEED)

cuda = torch.device("cuda")
cpu = torch.device("cpu")

if use_cuda:
    device = cuda
else:
    device = cpu
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# TODO: restore neural net parameters

actor = network.Actor(BOARD_XSIZE, BOARD_YSIZE).to(device)
critic = network.Critic(BOARD_XSIZE, BOARD_YSIZE).to(device)

actor_optimizer = optim.Adam(actor.parameters(), lr=network.ACTOR_LR)
critic_optimizer = optim.Adam(actor.parameters(), lr=network.CRITIC_LR)

# Get Writer
writer = SummaryWriter(log_dir=SUMMARY_DIR)

step=0

# %%
def agent(actor:network.Actor, critic:network.Critic) -> tuple[
    list[env.Observation],
    list[env.Action],
    list[env.Advantage],
    list[env.Value]
]:
    e = env.Env(DIMS)

    ACTOR_ID = np.int8(1)
    OPPONENT_ID = np.int8(2)

    s_batch:list[env.Observation] = []
    s_prime_batch:list[env.Observation] = []
    a_batch:list[env.Action] = []
    r_batch:list[env.Reward] = []
    actor_turn = True
    while not e.game_over():
        if actor_turn:
            obs = e.observe(ACTOR_ID)

            action_probs = actor.forward(network.obs_to_tensor(obs, device))[0].to(cpu).detach().numpy()
            if np.isnan(action_probs).any():
                raise ValueError("NaN found!")
            
            action_logprobs = np.log(action_probs)

            # apply noise to probs
            noise = 0.1*np.random.gumbel(size=len(action_logprobs))
            adjusted_action_probs = softmax(action_logprobs + noise) 

            legal_mask = e.legal_mask() 

            chosen_action: env.Action = np.argmax(adjusted_action_probs*legal_mask)

            s_batch.append(obs)

            reward,obs_prime = e.step(chosen_action, ACTOR_ID)
            
            s_prime_batch.append(obs_prime)
            a_batch.append(chosen_action)
            r_batch.append(reward)
        else:
            legal_mask = e.legal_mask()
            action_prob = np.random.random(size=BOARD_XSIZE)
            chosen_action: env.Action = np.argmax(action_prob*legal_mask)
            e.step(chosen_action, OPPONENT_ID)
            # else:
            #     obs = e.observe(OPPONENT_ID)
            #     action_prob = actor.predict_batch([obs])[0]
            #     legal_mask = e.legal_mask() 
            #     chosen_action: env.Action = np.argmax(action_prob*legal_mask)
            #     e.step(chosen_action, OPPONENT_ID)
            
        # flip turn
        actor_turn = not actor_turn

    v_batch = network.compute_value(r_batch)
    d_batch = network.compute_advantage(critic, s_batch, r_batch)

    return (s_batch, a_batch, d_batch, v_batch)


summary_reward_buf:list[float] = []
for epoch in range(TRAIN_EPOCHS):
    s_batch:list[env.Observation] = []
    a_batch:list[env.Action] = []
    d_batch:list[env.Advantage] = []
    v_batch:list[env.Value] = []
    for _ in range(EPISODES_PER_AGENT):
        s_, a_, d_, v_  = agent(actor, critic)
        s_batch += s_
        a_batch += a_
        d_batch += d_
        v_batch += v_
        summary_reward_buf.append(float(v_[-1]))
        
    actor_loss, critic_loss = network.train(actor, critic, actor_optimizer, critic_optimizer, s_batch, a_batch, d_batch, v_batch)
    writer.add_scalar('actor_loss', actor_loss, step)
    writer.add_scalar('critic_loss', critic_loss, step)

    if epoch % SUMMARY_STATS_INTERVAL == 0:
        avg_reward = sum(summary_reward_buf)/len(summary_reward_buf)
        writer.add_scalar('avg_reward', avg_reward, step)
        # clear
        summary_reward_buf = []
    
    if epoch % MODEL_SAVE_INTERVAL == 0:
        # Save the neural net parameters to disk.
        actor_path = f"{SUMMARY_DIR}/nn_model_ep_{epoch}_actor.ckpt"
        critic_path = f"{SUMMARY_DIR}/nn_model_ep_{epoch}_critic.ckpt"
        torch.save(actor.state_dict(), actor_path)
        torch.save(critic.state_dict(), critic_path)
    
    step += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 70
#      68 v_batch:list[env.Value] = []
#      69 for _ in range(EPISODES_PER_AGENT):
# ---> 70     s_, a_, d_, v_  = agent(actor, critic)
#      71     s_batch += s_
#      72     a_batch += a_
#
# Cell In[21], line 25, in agent(actor, critic)
#      22 action_logprobs = np.log(action_probs)
#      24 if np.isnan(action_logprobs).any():
# ---> 25     raise ValueError("NaN found!")
#      27 # apply noise to probs
#      28 noise = 0.1*np.random.gumbel(size=len(action_logprobs))
#
# ValueError: NaN found!

# %%
list(actor.parameters())
# Out:
# [Parameter containing:
#  tensor([[[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[-0.2162, -0.3306, -0.2304],
#            [-0.1490, -0.2258,  0.1059],
#            [ 0.0896,  0.0538, -0.3124]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[-0.3270,  0.0359,  0.2394],
#            [ 0.1936,  0.1125,  0.0937],
#            [-0.2971, -0.2167, -0.3498]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[-0.1601, -0.2161, -0.0322],
#            [-0.2483, -0.1187, -0.2205],
#            [ 0.0638, -0.3030, -0.0809]]],
#
#
#          [[[-0.2839, -0.2774, -0.1949],
#            [ 0.1640, -0.2083,  0.1089],
#            [-0.0261,  0.0837, -0.0573]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]],
#
#
#          [[[    nan,     nan,     nan],
#            [    nan,     nan,     nan],
#            [    nan,     nan,     nan]]]], device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([    nan,     nan,     nan,     nan,     nan,     nan, -0.0033,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#          -0.1728,     nan, -0.0447,  0.0745,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan],
#         device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([[[[-2.2869e-02, -3.7388e-02, -5.4857e-02],
#            [ 2.0288e-02, -5.2006e-02, -4.1954e-02],
#            [-2.9558e-05, -4.7767e-02,  1.4972e-02]],
#
#           [[ 5.0085e-02, -4.6640e-02, -1.5762e-02],
#            [-4.1529e-02,  4.6296e-03, -2.5711e-02],
#            [ 4.7329e-02, -2.0612e-02,  4.1089e-03]],
#
#           [[-2.1337e-02,  5.8018e-02,  1.8438e-02],
#            [ 4.2781e-02, -4.5484e-02,  1.8906e-02],
#            [-2.4478e-02,  2.8480e-03, -3.1688e-02]],
#
#           ...,
#
#           [[-1.6185e-02, -2.3356e-02, -4.3642e-02],
#            [ 3.2969e-03, -3.2315e-02,  3.1603e-02],
#            [ 4.7437e-02, -5.0110e-02, -2.0598e-02]],
#
#           [[ 5.5350e-04, -1.4395e-02,  3.0382e-02],
#            [-4.9098e-02,  4.5007e-02, -2.5566e-02],
#            [ 3.0281e-02, -2.4683e-02, -1.3246e-03]],
#
#           [[-4.2467e-02,  1.5366e-02,  3.0222e-02],
#            [-4.0970e-02,  4.3726e-02,  6.0260e-02],
#            [-2.1999e-03,  2.4571e-02,  3.3562e-02]]],
#
#
#          [[[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           ...,
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]]],
#
#
#          [[[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           ...,
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]]],
#
#
#          ...,
#
#
#          [[[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           ...,
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]]],
#
#
#          [[[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           ...,
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]]],
#
#
#          [[[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           ...,
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]],
#
#           [[        nan,         nan,         nan],
#            [        nan,         nan,         nan],
#            [        nan,         nan,         nan]]]], device='cuda:0',
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0377,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan, -0.0355,     nan,     nan, -0.0128,  0.0583,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan],
#         device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([[    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [-0.0620,  0.0522, -0.0020,  ..., -0.0655, -0.0622, -0.0356],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          ...,
#          [-0.0625,  0.0462,  0.0515,  ..., -0.0092,  0.0089,  0.0639],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]],
#         device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([    nan, -0.0223,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,  0.0629,     nan,     nan, -0.0461,
#              nan,     nan,  0.0608,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,  0.0672,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan, -0.0185,     nan, -0.0328,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan, -0.0137, -0.0638,     nan,     nan, -0.0464,     nan,     nan,
#              nan,     nan,     nan,     nan,  0.0321,     nan,  0.0497,     nan,
#          -0.0542,     nan,     nan,     nan,  0.0456,     nan,     nan,     nan,
#          -0.0022,     nan,     nan, -0.0372,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,  0.0124,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan, -0.0083,  0.0459,     nan,     nan,
#              nan, -0.0729,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,  0.0356,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,  0.0315,     nan,     nan,
#              nan,     nan,     nan,  0.0397,     nan,     nan,     nan, -0.0287,
#              nan,     nan, -0.0147,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan, -0.0643,     nan,     nan,     nan,  0.0538,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan, -0.0660,     nan,
#              nan,     nan, -0.0418,  0.0467,     nan, -0.0496,  0.0172,     nan,
#           0.0084,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,  0.0217,     nan,  0.0216,     nan,     nan,     nan,
#              nan, -0.0104,     nan,     nan,     nan,     nan,     nan, -0.0076,
#              nan,     nan,     nan,     nan,  0.0639,     nan,     nan,     nan,
#           0.0439,     nan,     nan, -0.0053, -0.0062,     nan,     nan,     nan,
#              nan,     nan,     nan,  0.0429,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan, -0.0469,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan, -0.0082,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,  0.0254,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan, -0.0208,
#              nan,     nan, -0.0270, -0.0142,     nan,     nan,     nan,     nan,
#              nan, -0.0147,  0.0663, -0.0144, -0.0556, -0.0414,  0.0164,     nan,
#              nan,     nan,     nan, -0.0393,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,  0.0077,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan, -0.0562,     nan,     nan, -0.0056,     nan,  0.0399,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#          -0.0712,     nan, -0.0301,     nan,     nan, -0.0203,     nan,     nan,
#          -0.0030, -0.0283,     nan,     nan, -0.0157,     nan,     nan,     nan,
#           0.0063,     nan,     nan,     nan,     nan,     nan,  0.0425,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,  0.0509,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan, -0.0176,     nan,     nan,     nan,     nan,
#              nan,     nan, -0.0427,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan, -0.0526,     nan,
#              nan,  0.0687,     nan, -0.0725,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan, -0.0665,     nan,     nan, -0.0548,     nan,     nan,  0.0024,
#              nan,     nan,     nan, -0.0081,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan, -0.0732,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan, -0.0165,
#              nan, -0.0680,     nan,  0.0127,     nan,     nan,  0.0213,     nan,
#              nan,     nan,     nan,     nan,  0.0334,     nan,     nan, -0.0469,
#          -0.0210,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#           0.0033,     nan,     nan,     nan,     nan,     nan,     nan,  0.0122,
#              nan, -0.0597,     nan, -0.0153,     nan,     nan,  0.0403,     nan,
#          -0.0690,     nan, -0.0733,     nan,     nan, -0.0342,     nan,     nan,
#              nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan,  0.0592,     nan,     nan, -0.0089,     nan,     nan,
#              nan,     nan,     nan,  0.0710,     nan,     nan,     nan,     nan,
#              nan,  0.0668,  0.0612,     nan,     nan,  0.0639,     nan,     nan],
#         device='cuda:0', requires_grad=True),
#  Parameter containing:
#  tensor([[nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          ...,
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan],
#          [nan, nan, nan,  ..., nan, nan, nan]], device='cuda:0',
#         requires_grad=True),
#  Parameter containing:
#  tensor([        nan,         nan,         nan,  3.0339e-02,         nan,
#                  nan,         nan, -2.6398e-02,  3.9329e-04,         nan,
#          -3.3994e-02,         nan, -3.9998e-02,         nan, -1.1422e-02,
#                  nan,         nan,         nan,         nan,         nan,
#                  nan,  3.6402e-03,  3.7646e-02, -5.3267e-05,         nan,
#           4.5784e-02,         nan,         nan,         nan, -7.9036e-04,
#          -3.8812e-02,         nan,  4.0956e-02,         nan,         nan,
#           3.1312e-02,  3.5525e-02,         nan,         nan,         nan,
#          -5.9236e-03, -1.4774e-02, -4.2717e-02, -3.4490e-02,         nan,
#                  nan,         nan,         nan,         nan,         nan,
#                  nan,         nan, -3.9941e-02,         nan, -3.7252e-02,
#                  nan, -4.1655e-02, -3.8533e-02,         nan, -2.1424e-03,
#                  nan, -2.3773e-02,         nan,         nan,         nan,
#                  nan,         nan,         nan,  3.1356e-02,         nan,
#          -1.3169e-02, -2.6459e-03,         nan, -1.6587e-02,         nan,
#                  nan, -2.1935e-02,         nan,         nan,         nan,
#                  nan,         nan,  1.5898e-02,  5.3695e-03,  1.0691e-02,
#                  nan,         nan,         nan,         nan,         nan,
#           2.7781e-02,         nan,         nan,         nan,         nan,
#                  nan,         nan,         nan,         nan,         nan,
#                  nan,         nan,         nan,         nan,         nan,
#                  nan,         nan,         nan, -3.4274e-02,  3.5750e-02,
#                  nan, -4.4744e-02, -3.3489e-02,         nan,         nan,
#          -1.2776e-03,         nan,         nan,         nan,         nan,
#                  nan,  1.6804e-02,         nan,         nan,         nan,
#                  nan,         nan,         nan], device='cuda:0',
#         requires_grad=True),
#  Parameter containing:
#  tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#           nan, nan, nan, nan, nan, nan, nan, nan]], device='cuda:0',
#         requires_grad=True),
#  Parameter containing:
#  tensor([nan, nan, nan, nan, nan, nan, nan], device='cuda:0',
#         requires_grad=True)]

# %%
e = env.Env(DIMS)

e.step(3, 1)
e.step(3, 2)
o = e.observe(1)
print(e.legal_mask())
env.print_obs(o)
actor.forward(network.obs_to_tensor(o, device))[0]
# Out:
# [ True  True  True  True  True  True  True]
#
#
#
#
#       O
#       #
# tensor([nan, nan, nan, nan, nan, nan, nan], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
s_tensor = network.obs_batch_to_tensor(s_batch, device)
critic_guesses = critic.forward(s_tensor).to(cpu).detach().numpy()
actor_guesses = actor.forward(s_tensor).to(cpu).detach().numpy()
for v, obs, critic_guess, actor_guess in zip(v_batch, s_batch, critic_guesses, actor_guesses):
    print("real_value", v)
    print("pred_value", float(critic_guess))
    print("actor_probs", np.array(actor_guess))
    env.print_obs(obs)
    print('0 1 2 3 4 5 6 7')
# Out:
# real_value 0.0
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.007051178719848394
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #         O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01274698693305254
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #   O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.014531351625919342
# actor_probs [nan nan nan nan nan nan nan]
#
#
# O
# #
# #
# #   O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.015428484417498112
# actor_probs [nan nan nan nan nan nan nan]
#
# #
# O
# #
# #
# #   O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.014015091583132744
# actor_probs [nan nan nan nan nan nan nan]
# #
# #
# O
# #
# #
# # O O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.40960000000000013
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.00855556782335043
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# O
# #
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.013233925215899944
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# O
# #     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.011701606214046478
# actor_probs [nan nan nan nan nan nan nan]
#
#
# #
# #
# O
# # O   O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.006514762528240681
# actor_probs [nan nan nan nan nan nan nan]
#
# #
# #
# #
# O O
# # O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.003857904579490423
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# # O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.008001011796295643
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O       O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.013879038393497467
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.008007482625544071
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.01274698693305254
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #   O     O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.014223579317331314
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# #   O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.003857904579490423
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# # O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.00865305494517088
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.01348946150392294
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.006748695857822895
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.01260962150990963
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #     O   O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.006709262728691101
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #         O
# #     O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.00855556782335043
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# O
# #
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.010997875593602657
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# O
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.013978886418044567
# actor_probs [nan nan nan nan nan nan nan]
#
# O
# #
# #
# O
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01608390547335148
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# #
# O
# #       O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01747877150774002
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# #
# O           O
# #       O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.013468551449477673
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# #           O
# O           O
# #       O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.016054177656769753
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# #           O
# O           O
# #       O O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.006748695857822895
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.008119426667690277
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O   O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.01050905417650938
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O   O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.007944252341985703
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #       O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.00865305494517088
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.010757196694612503
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O     O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.006748695857822895
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.01011962816119194
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #   O O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.010308690369129181
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.007051178719848394
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #         O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.008001011796295643
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O       O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.011017588898539543
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O       O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.008007482625544071
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01290969830006361
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# O
# #
# #   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.014702203683555126
# actor_probs [nan nan nan nan nan nan nan]
#
# O
# #
# O
# #
# #   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.02378556691110134
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# #   O
# #   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.023322494700551033
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# #   O
# # O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.024707818403840065
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# #   O
# # O O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.022432470694184303
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# #   O
# # O O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.019816307350993156
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# # O O
# # O O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.014486249536275864
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# # O O     O
# # O O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.014899083413183689
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O
# # O O     O
# # O O O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01963100954890251
# actor_probs [nan nan nan nan nan nan nan]
# #
# O
# #
# O         O
# # O O     O
# # O O O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.005759491119533777
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.011610494926571846
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# O
# #
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01341340597718954
# actor_probs [nan nan nan nan nan nan nan]
#
#
# #
# O
# #
# #         O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.016114916652441025
# actor_probs [nan nan nan nan nan nan nan]
#
# #
# #
# O
# #           O
# #         O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.02000235579907894
# actor_probs [nan nan nan nan nan nan nan]
# #
# #
# #
# O
# #           O
# #   O     O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01974690519273281
# actor_probs [nan nan nan nan nan nan nan]
# #
# #
# #
# O
# #           O
# #   O O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.023910563439130783
# actor_probs [nan nan nan nan nan nan nan]
# #
# #
# #
# O
# #   O       O
# #   O O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.02642856352031231
# actor_probs [nan nan nan nan nan nan nan]
# #
# #
# #
# O   O
# #   O       O
# #   O O   O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.007944252341985703
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #       O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.012234714813530445
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #     O O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.013736285269260406
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# #     O O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.006748695857822895
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.01011962816119194
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #   O O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.010308690369129181
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.003857904579490423
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# # O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.00865305494517088
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.010681579820811749
# actor_probs [nan nan nan nan nan nan nan]
#
#
# O
# #
# #
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01006684172898531
# actor_probs [nan nan nan nan nan nan nan]
# O
# #
# O
# #
# #
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.01377881970256567
# actor_probs [nan nan nan nan nan nan nan]
# O
# #
# O
# #
# #       O
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.0
# pred_value -0.010222813114523888
# actor_probs [nan nan nan nan nan nan nan]
# O
# #
# O
# #       O
# #       O
# # O     O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.005759491119533777
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.010750822722911835
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# #       O   O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.013393529690802097
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #           O
# #       O   O
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.005759491119533777
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
# #           O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.008009152486920357
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# #
# # O         O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.011017588898539543
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# #
# # O       O O
#
# 0 1 2 3 4 5 6 7
# real_value 0.40960000000000013
# pred_value -0.0017231465317308903
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
#
#
#
# 0 1 2 3 4 5 6 7
# real_value 0.5120000000000001
# pred_value -0.00855556782335043
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
#
# O
# #
#
# 0 1 2 3 4 5 6 7
# real_value 0.6400000000000001
# pred_value -0.008525751531124115
# actor_probs [nan nan nan nan nan nan nan]
#
#
#
# #
# O
# # O
#
# 0 1 2 3 4 5 6 7
# real_value 0.8
# pred_value -0.004101082682609558
# actor_probs [nan nan nan nan nan nan nan]
#
#
# #
# #
# O O
# # O
#
# 0 1 2 3 4 5 6 7
# real_value 1.0
# pred_value -0.001712725032120943
# actor_probs [nan nan nan nan nan nan nan]
#
# #
# #
# # O
# O O
# # O
#
# 0 1 2 3 4 5 6 7
